# %%
import pandas as pd
import os; import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from utils.plots import *

# %%
print(os.getcwd())
# Out:
# /home/kaleem/courses/CSS/ants-mesa/notebooks

# %% [markdown]
# # Probability of Random Movement

# %%
main("../data/prob_random.csv", "prob_random")
# Out:
# prob_random
# 0.000000    0.0
# 0.111111    0.0
# 0.222222    0.0
# 0.333333    0.0
# 0.444444    0.0
# 0.555556    0.0
# 0.666667    0.0
# 0.777778    0.0
# 0.888889    0.0
# 1.000000    0.0
# Name: Ants 🐜, dtype: float64
# prob_random
# 0.000000    25.342104
# 0.111111    27.704793
# 0.222222     6.819091
# 0.333333    38.761378
# 0.444444    38.115176
# 0.555556    28.448784
# 0.666667    22.832968
# 0.777778     9.900056
# 0.888889     6.113737
# 1.000000     6.373556
# Name: Home 🏠, dtype: float64

# %%
main("data/num_ants.csv", "num_ants", "Ants 🐜")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 main("data/num_ants.csv", "num_ants", "Ants 🐜")
#
# NameError: name 'main' is not defined

# %%
from utils.experiments import *
params = {
    "num_ants": 150
}

results_num_ants = run_experiment(steps=500, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [00:53<00:00, 10.67s/it]

# %%
plot_results(results_num_ants, steps=500)

# %%
from plots import plot_powerlaw
plot_powerlaw(np.array(results_num_ants["food_collected"]).flatten())
# Out:
# Calculating best minimal value for power law fit
# Alpha: 8.74480955565483
# Xmin: 25.0
# R: -6.953725553044576
# p: 0.024667551918730872
# Fitted α (alpha): 8.74
# Fitted x_min: 25.00
# Standard error in α: 0.34
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %%
from utils.experiments import *
params = {
    "num_ants": 250
}

results_num_ants = run_experiment(steps=500, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [00:50<00:00, 10.11s/it]

# %%
plot_results(results_num_ants, steps=500)

# %%
fit = powerlaw.Fit(np.array(results_num_ants["food_collected"]).flatten())

alpha = fit.alpha
print(f"Estimated alpha: {alpha}")

R, p = fit.distribution_compare('power_law', 'exponential')
print(f"Log-likelihood ratio: {R}")
print(f"P-value for comparison: {p}")
    
if p < 0.05:
    print("Power law fit is better than exponential fit")
else:
    print("Exponential fit is as good or better than power law fit")

plt.figure(figsize=(8, 6))
fit.plot_pdf(color='blue', linestyle='-', marker='o', label='Empirical Data')
fit.power_law.plot_pdf(color='red', linestyle='--', label='Power Law Fit')
plt.xlabel("Food Collected")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calculating best minimal value for power law fit
# Estimated alpha: 2.4508016095946505
# Log-likelihood ratio: 42.6143296719131
# P-value for comparison: 2.432962074982533e-05
# Power law fit is better than exponential fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %%
params = {
    "max_steps_without_food": 80
}

results_max_steps_without_food = run_experiment(steps=500, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [00:51<00:00, 10.23s/it]

# %%
plot_results(results_max_steps_without_food, steps=500)

# %%
fit = powerlaw.Fit(np.array(results_max_steps_without_food["food_collected"]).flatten())

alpha = fit.alpha
print(f"Estimated alpha: {alpha}")

R, p = fit.distribution_compare('power_law', 'exponential')
print(f"Log-likelihood ratio: {R}")
print(f"P-value for comparison: {p}")
    
if p < 0.05:
    print("Power law fit is better than exponential fit")
else:
    print("Exponential fit is as good or better than power law fit")

plt.figure(figsize=(8, 6))
fit.plot_pdf(color='blue', linestyle='-', marker='o', label='Empirical Data')
fit.power_law.plot_pdf(color='red', linestyle='--', label='Power Law Fit')
plt.xlabel("Food Collected")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calculating best minimal value for power law fit
# Estimated alpha: 1.7079066911952394
# Log-likelihood ratio: -274.822638226596
# P-value for comparison: 8.668536131402811e-30
# Power law fit is better than exponential fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %%
params = {
    "max_steps_without_food": 80
}
results_max_steps_without_food_2 = run_experiment(steps=300, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [00:31<00:00,  6.30s/it]

# %%
plot_results(results_max_steps_without_food_2, steps=300)

# %%
fit = powerlaw.Fit(np.array(results_max_steps_without_food["food_collected"]).flatten())

alpha = fit.alpha
print(f"Estimated alpha: {alpha}")

R, p = fit.distribution_compare('power_law', 'exponential')
print(f"Log-likelihood ratio: {R}")
print(f"P-value for comparison: {p}")
    
if p < 0.05:
    print("Power law fit is better than exponential fit")
else:
    print("Exponential fit is as good or better than power law fit")

plt.figure(figsize=(8, 6))
fit.plot_pdf(color='blue', linestyle='-', marker='o', label='Empirical Data')
fit.power_law.plot_pdf(color='red', linestyle='--', label='Power Law Fit')
plt.xlabel("Food Collected")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calculating best minimal value for power law fit
# Estimated alpha: 1.7079066911952394
# Log-likelihood ratio: -274.822638226596
# P-value for comparison: 8.668536131402811e-30
# Power law fit is better than exponential fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %%
import matplotlib.pyplot as plt

df = df[df["Step"] > 100]

avg_pheromone = df.groupby("RunId")["pheromone_ant_avg"].mean()
num_ants = df.groupby("RunId")["num_ants"].mean()
# print(avg_pheromone)
# print(num_ants)
plt.scatter(num_ants, avg_pheromone)

# %%
from utils.experiments import *

params = {
    "max_steps_without_food": 150
}
results_max_steps_without_food_2 = run_experiment(steps=500, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [00:47<00:00,  9.48s/it]

# %%
plot_results(results_max_steps_without_food_2, steps=500)

# %%
fit = powerlaw.Fit(np.array(results_max_steps_without_food_2["food_collected"]).flatten())

alpha = fit.alpha
print(f"Estimated alpha: {alpha}")

R, p = fit.distribution_compare('power_law', 'exponential')
print(f"Log-likelihood ratio: {R}")
print(f"P-value for comparison: {p}")
    
if p < 0.05:
    print("Power law fit is better than exponential fit")
else:
    print("Exponential fit is as good or better than power law fit")

plt.figure(figsize=(8, 6))
fit.plot_pdf(color='blue', linestyle='-', marker='o', label='Empirical Data')
fit.power_law.plot_pdf(color='red', linestyle='--', label='Power Law Fit')
plt.xlabel("Food Collected")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calculating best minimal value for power law fit
# Estimated alpha: 2.673300862952034
# Log-likelihood ratio: 47.67814440048949
# P-value for comparison: 6.651755369168952e-07
# Power law fit is better than exponential fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values

# %%
from utils.experiments import *

params = {
    "evaporate": 0.1
}
results_pheromone = run_experiment(steps=500, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [01:01<00:00, 12.31s/it]

# %%
plot_results(results_pheromone, steps=500)

# %%
def powerlaw_fit(X, Y):
    slope, y_intercept = np.polyfit(
        np.log(X),
        np.log(Y),
        deg=1
    )

    a = np.exp(y_intercept)
    b = slope

    return a, b

# %%
results_pheromone_array = results_pheromone[results_pheromone["Step"] > 100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 results_pheromone = results_pheromone[results_pheromone["Step"] > 100]
#
# KeyError: 'Step'

# %%
Y = np.array(results_pheromone["food_collected"]).flatten()

# %%
N = len(Y)
Y_unique, Y_freq = np.unique(Y, return_counts=True)
Y_freq = Y_freq / N
Y_err = 1.96 * np.sqrt(Y_freq * (1 - Y_freq) / N)

X_fit = Y_unique[:9]
Y_fit = Y_freq[:9]

a, b = powerlaw_fit(X_fit, Y_fit)

Y_pred = a * Y_unique ** b

fig, ax = plt.subplots()

ax.errorbar(
    Y_unique,
    Y_freq,
    yerr=Y_err,
    label='Empirical Data'
)
ax.plot(Y_unique, Y_pred, label='Powerlaw Fit', color='black', linestyle='--')
ax.loglog()
ax.set_xlabel("Meal sizes")
ax.set_ylabel("Probability density")
ax.legend()
plt.show()
# Out:
#  ** On entry to DLASCL parameter number  4 had an illegal value
#  ** On entry to DLASCL parameter number  4 had an illegal value
#  ** On entry to DLASCL parameter number  4 had an illegal value
#  ** On entry to DLASCL parameter number  4 had an illegal value
#  ** On entry to DLASCL parameter number  5 had an illegal value
#  ** On entry to DLASCL parameter number  4 had an illegal value
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[77], line 9
#       6 X_fit = Y_unique[:9]
#       7 Y_fit = Y_freq[:9]
# ----> 9 a, b = powerlaw_fit(X_fit, Y_fit)
#      11 Y_pred = a * Y_unique ** b
#      13 fig, ax = plt.subplots()
#
# Cell In[66], line 2, in powerlaw_fit(X, Y)
#       1 def powerlaw_fit(X, Y):
# ----> 2     slope, y_intercept = np.polyfit(
#       3         np.log(X),
#       4         np.log(Y),
#       5         deg=1
#       6     )
# ...

# %%
fit = powerlaw.Fit(np.array(results_pheromone["ants"]).flatten())

alpha = fit.alpha
print(f"Estimated alpha: {alpha}")

R, p = fit.distribution_compare('power_law', 'exponential')
print(f"Log-likelihood ratio: {R}")
print(f"P-value for comparison: {p}")
    
if p < 0.05:
    print("Power law fit is better than exponential fit")
else:
    print("Exponential fit is as good or better than power law fit")

plt.figure(figsize=(8, 6))
fit.plot_pdf(color='blue', linestyle='-', marker='o', label='Empirical Data')
fit.power_law.plot_pdf(color='red', linestyle='--', label='Power Law Fit')
plt.xlabel("Ant Count")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Calculating best minimal value for power law fit
# Estimated alpha: 2.1389790243623237
# Log-likelihood ratio: -56.10843475020232
# P-value for comparison: 0.0004165338838904128
# Power law fit is better than exponential fit

# %%
params = {
    "evaporate": 0.4
}

results_pheromone_2 = run_experiment(steps=500, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [00:59<00:00, 11.82s/it]

# %%
fit = powerlaw.Fit(np.array(results_pheromone_2["ants"]).flatten())

alpha = fit.alpha
print(f"Estimated alpha: {alpha}")

R, p = fit.distribution_compare('power_law', 'exponential')
print(f"Log-likelihood ratio: {R}")
print(f"P-value for comparison: {p}")
    
if p < 0.05:
    print("Power law fit is better than exponential fit")
else:
    print("Exponential fit is as good or better than power law fit")

plt.figure(figsize=(8, 6))
fit.plot_pdf(color='blue', linestyle='-', marker='o', label='Empirical Data')
fit.power_law.plot_pdf(color='red', linestyle='--', label='Power Law Fit')
plt.xlabel("Food Collected")
plt.ylabel("Probability Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# Estimated alpha: 846.2369612903373
# Log-likelihood ratio: nan
# P-value for comparison: nan
# Exponential fit is as good or better than power law fit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/CSS/lib/python3.11/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/CSS/lib/python3.11/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# ...

# %%
params = {
    "prob_random": 0.4
}

results_prob_random = run_experiment(steps=500, runs=5, params=params)
# Out:
# ...
# 100%|██████████| 5/5 [01:05<00:00, 13.12s/it]

# %%
plot_results(results_pheromone_2, steps=500)

# %%
df = pd.read_csv("../data/prob_random.csv")
df_grouped = df.groupby("prob_random")

mean = {}
std = {}

for name, group in df_grouped:
    mean[name] = group["Home 🏠"].mean()
    std[name] = group["Home 🏠"].std()

plt.plot(list(mean.keys()), list(mean.values()), marker='o')
plt.fill_between(list(mean.keys()), [mean[k] - std[k] for k in mean.keys()], [mean[k] + std[k] for k in mean.keys()], alpha=0.3)
plt.xlabel("Random Probability")
plt.ylabel("Home 🏠")
plt.show()

# %%
# Out:
#       RunId  iteration  Step  prob_random  Ants 🐜  Predators  Food 🍯  Home 🏠  \
# 0         9          0   500     0.290323     372          4     445     406
# 1        11          0   500     0.354839     115          3     589     271
# 2         5          0   500     0.161290      37          3     758     128
# 3         2          0   500     0.064516     756          3     599     292
# 4         7          0   500     0.225806     243          3     533     302
# ...     ...        ...   ...          ...     ...        ...     ...     ...
# 1019   1017         31   500     0.806452    1370          4     433     424
# 1020   1022         31   500     0.967742       1          3     875      23
# 1021   1021         31   500     0.935484     158          3     831      63
# 1022   1023         31   500     1.000000       7          3     875      24
# 1023   1020         31   500     0.903226     481          5     693     173
#
# ...

# %%
from utils.plots import *

# %%
import numpy as np
df = load_and_prepare_data("../data/prob_random.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 import numpy as np
# ----> 2 df = load_and_prepare_data("../data/prob_random.csv")
#
# File ~/courses/CSS/ants-mesa/utils/plots.py:27, in load_and_prepare_data(file_path)
#      25 # Convert entropy_log from string to list and extract last recorded entropy value
#      26 if df["entropy_log"].dtype == "object":
# ---> 27     df["Final Entropy"] = df["entropy_log"].apply(lambda x: eval(x)[-1] if isinstance(x, str) else None)
#      29 return df
#
# File ~/miniconda3/envs/CSS/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
# ...

# %%
df["entropy_log"]
# Out:
# '[2.086673901075005, 2.425479704683253, 2.4632808831743667, 2.6895357734679943, 2.6895357734679948, 2.6895357734679943, 2.6895357734679948, 2.6895357734679948, 2.9020023132056036, 2.9650156932565075, 3.014946880179594, 2.954673212304816, 3.120291565301285, 3.107972275978608, 2.9915014685753505, 2.938182454686124, 3.019736127138996, 3.084651945689509, 3.2058430290511555, 3.2058430290511555, 3.128279560827872, 3.2058430290511555, 3.2058430290511555, 3.2716893223230326, 3.1580397752194354, 3.2536462828828756, 3.2716893223230326, 3.2716893223230326, 3.3194925761547527, 3.3194925761547527, 3.2716893223230326, 3.2238860684913124, 3.198916528720685, 3.2625679455501664, 3.3549875696248255, 3.3549875696248255, 3.327669886226942, 3.3445488586064434, 3.422414204014729, 3.422414204014729, 3.422414204014729, 3.3790925052297323, 3.422414204014729, 3.4657359027997265, 3.422414204014729, 3.422414204014729, 3.5447609852749897, 3.2382315403482393, 3.4106034664569354, 3.5000418123356383, 3.465735902799
# ...

# %%
plot_entropy_shifts(df, "prob_random", column="entropy")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 plot_entropy_shifts(df, "prob_random", column="entropy")
#
# File ~/courses/CSS/ants-mesa/utils/plots.py:43, in plot_entropy_shifts(df, ax, groupby, column)
#      41 def plot_entropy_shifts(df, ax=None, groupby="max_steps_without_food", column="Final Entropy"):
#      42     """Plots entropy shifts to analyze self-organization in the system."""
# ---> 43     entropy_data = df.groupby(groupby)[column].mean()
#      45     # plt.figure(figsize=(8, 5))
#      46     ax.plot(entropy_data.index, entropy_data.values, marker='s', linestyle='-', color="purple", label="Mean Entropy")
#
# File ~/miniconda3/envs/CSS/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
# ...

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 8))
plot_mean_std(df_grouped, ax1, column="Home 🏠")
plot_mean_std(df_grouped, ax2, column="Ants 🐜")
ax2.set_xlabel("Random Move Probability")
ax1.set_ylabel("Food collected")
ax2.set_ylabel("Number of Ants")
# Out:
# Text(0, 0.5, 'Number of Ants')
